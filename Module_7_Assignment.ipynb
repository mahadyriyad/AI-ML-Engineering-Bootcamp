# %% [markdown]
# ### Question 1: Dataset Loading and Initial Exploration

# %%
import pandas as pd

# Load the dataset (assuming heart.csv is available in the content directory)
# Since 'df' is already in the kernel, we will just display the info.
print("First five rows of the dataset:")
display(df.head())
# Out:
# First five rows of the dataset:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
print("Last five rows of the dataset:")
display(df.tail())
# Out:
# Last five rows of the dataset:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
print("Shape of the dataset (rows, columns):")
print(df.shape)
# Out:
# Shape of the dataset (rows, columns):
# (1025, 14)

# %% [markdown]
# ### Question 2: Dataset Structure and Missing Value Analysis

# %%
print("Column Names:")
print(df.columns.tolist())
# Out:
# Column Names:
# ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']

# %%
print("Dataset Information (data types and non-null counts):")
df.info()
# Out:
# Dataset Information (data types and non-null counts):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
print("Missing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# ### Question 3: Categorical Data Analysis

# %%
print("Count of patients with heart disease (target=1) and without (target=0):")
display(df['target'].value_counts())
# Out:
# Count of patients with heart disease (target=1) and without (target=0):
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
print("Count of male (sex=1) and female (sex=0) patients:")
display(df['sex'].value_counts())
# Out:
# Count of male (sex=1) and female (sex=0) patients:
# sex
# 1    713
# 0    312
# Name: count, dtype: int64

# %% [markdown]
# ### Question 4: Data Selection Using iloc

# %%
print("First 10 rows of the dataset using iloc:")
display(df.iloc[:10])
# Out:
# First 10 rows of the dataset using iloc:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# ...

# %%
# Assuming 'age' is at index 0, 'sex' at index 1, and 'chol' at index 4 based on the df.info() output
print("Columns 'age', 'sex', and 'cholesterol' using iloc:")
display(df.iloc[:, [0, 1, 4]])
# Out:
# Columns 'age', 'sex', and 'cholesterol' using iloc:
#       age  sex  chol
# 0      52    1   212
# 1      53    1   203
# 2      70    1   174
# 3      61    1   203
# 4      62    0   294
# ...   ...  ...   ...
# 1020   59    1   221
# 1021   60    1   258
# 1022   47    1   275
# 1023   50    0   254
# 1024   54    1   188
#
# [1025 rows x 3 columns]

# %%
print("Rows from index 20 to 30 and columns from index 0 to 4 using iloc:")
display(df.iloc[20:31, 0:5])
# Out:
# Rows from index 20 to 30 and columns from index 0 to 4 using iloc:
#     age  sex  cp  trestbps  chol
# 20   60    1   2       140   185
# 21   67    0   0       106   223
# 22   45    1   0       104   208
# 23   63    0   2       135   252
# 24   42    0   2       120   209
# 25   61    0   0       145   307
# 26   44    1   2       130   233
# 27   58    0   1       136   319
# 28   56    1   2       130   256
# 29   55    0   0       180   327
# 30   44    1   0       120   169

# %% [markdown]
# ### Question 5: Data Filtering Using Conditions

# %%
print("Patients older than 50 years:")
display(df[df['age'] > 50].head())
# Out:
# Patients older than 50 years:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
print("Patients with heart disease (target=1) and cholesterol > 240:")
display(df[(df['target'] == 1) & (df['chol'] > 240)].head())
# Out:
# Patients with heart disease (target=1) and cholesterol > 240:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 5    58    0   0       100   248    0        0      122      0      1.0
# 16   51    0   2       140   308    0        0      142      0      1.5
# 18   50    0   1       120   244    0        1      162      0      1.1
# 23   63    0   2       135   252    0        0      172      0      0.0
# 31   50    0   1       120   244    0        1      162      0      1.1
#
#     slope  ca  thal  target
# 5       1   0     2       1
# 16      2   1     2       1
# 18      2   0     2       1
# 23      2   0     2       1
# 31      2   0     2       1

# %%
print("Count of patients with heart disease (target=1) and cholesterol > 240:")
print(len(df[(df['target'] == 1) & (df['chol'] > 240)]))
# Out:
# Count of patients with heart disease (target=1) and cholesterol > 240:
# 222
