# %% [markdown]
# # Q1
# Basic Print

# %%
print("Welcome to Python Programming!")
print("I am learning the basics.")
# Out:
# Welcome to Python Programming!
# I am learning the basics.

# %% [markdown]
# # Q2
# Print with Variables

# %%
name = "Riyad"
age = 23

print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Riyad and I am 23 years old.

# %% [markdown]
# # Q3
# User Input

# %%
name = input("Enter your name: ")
language = input("Enter your favorite programming language: ")

print(f"Hello {name}, your favorite language is {language}.")
# Out:
# Enter your name: Riyad
# Enter your favorite programming language: js
# Hello Riyad, your favorite language is js.

# %% [markdown]
# # Q4
# Type Casting — String to Integer

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

total = num1 + num2
print(f"The sum is: {total}")
# Out:
# Enter first number: 7
# Enter second number: 13
# The sum is: 20

# %% [markdown]
# # Q5
# Simple Calculator

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print(f"Addition: {num1 + num2}")
print(f"Subtraction: {num1 - num2}")
print(f"Multiplication: {num1 * num2}")
# Out:
# Enter first number: 9
# Enter second number: 12
# Addition: 21
# Subtraction: -3
# Multiplication: 108
